# %%
import requests

url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/2244/synonyms/JSON"
res = requests.get(url, timeout=20)

print(res.status_code)
print(res.headers.get("X-Throttling-Control"))
print(res.text[:300])
# Out:
# 503
# Request Count status: Green (0%), Request Time status: Green (0%), Service status: Yellow (67%), too many requests per second or blacklisted
# {
#   "Fault": {
#     "Code": "PUGREST.ServerBusy",
#     "Message": "Too many requests or server too busy"
#   }
# }
