# %%
import json
import pandas as pd

with open('./additives.json', 'rb') as file:
    data = json.load(file)

mapping_df = pd.read_csv('./additive_id_mapping.csv')

print(len(data.keys()))

print(len(set(mapping_df['id'].values.tolist())))
# Out:
# 126
# 124
